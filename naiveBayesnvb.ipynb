# %%
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score, classification_report
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split

df = pd.read_csv('NaiveBayes.csv')
df
# Out:
#      Age  Salary  Purchased
# 0     19   19000          0
# 1     35   20000          0
# 2     26   43000          0
# 3     27   57000          0
# 4     19   76000          0
# ..   ...     ...        ...
# 395   46   41000          1
# 396   51   23000          1
# 397   50   20000          1
# 398   36   33000          0
# 399   49   36000          1
#
# [400 rows x 3 columns]

# %%
df.isnull().sum()
# Out:
# Age          0
# Salary       0
# Purchased    0
# dtype: int64

# %%
for cols in df.columns:
  print(cols, (df[cols] == 0).sum())
# Out:
# Age 0
# Salary 0
# Purchased 257

# %%
X = df.drop(columns=["Purchased"])
y = df["Purchased"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# %%
model = GaussianNB()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
# print(classification_report(y_test, y_pred))
from sklearn.metrics import precision_score, recall_score, f1_score
print(accuracy_score(y_test, y_pred))
print(precision_score(y_test, y_pred))
print(recall_score(y_test, y_pred))
print(f1_score(y_test, y_pred))
# Out:
# 0.91
# 0.84375
# 0.8709677419354839
# 0.8571428571428571

# %%
df
# Out:
#      Age  Salary  Purchased
# 0     19   19000          0
# 1     35   20000          0
# 2     26   43000          0
# 3     27   57000          0
# 4     19   76000          0
# ..   ...     ...        ...
# 395   46   41000          1
# 396   51   23000          1
# 397   50   20000          1
# 398   36   33000          0
# 399   49   36000          1
#
# [400 rows x 3 columns]

# %%
age = int(input("Enter Age: "))
sal = int(input("Enter Salary: "))

new_df = np.array([[age, sal]])
new_pred = model.predict(new_df)
print(new_pred[0])
# Out:
# Enter Age: 20
# Enter Salary: 8957567
# 1
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score, classification_report
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split

df = pd.read_csv('data.csv')
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
print(df.isnull().sum())
# Out:
# Duration    0
# Pulse       0
# Maxpulse    0
# Calories    0
# dtype: int64

# %%
df["Calories"] = df["Calories"].fillna(df["Calories"].median())

# %%
for cols in df.columns:
  print(cols, (df[cols] == 0).sum())
# Out:
# Duration 0
# Pulse 0
# Maxpulse 0
# Calories 0

# %%
X = df.drop(columns=["Calories"])
y = df["Calories"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# %%
model = GaussianNB()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-c374943eaadc> in <cell line: 2>()
#       1 model = GaussianNB()
# ----> 2 model.fit(X_train, y_train)
#       3 y_pred = model.predict(X_test)
#       4 print(X_train.shape)
#       5 print(X_test.shape)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#    1474
#    1475         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/sklearn/naive_bayes.py in fit(self, X, y, sample_weight)
#     261         """
#     262         y = self._validate_data(y=y)
# --> 263         return self._partial_fit(
#     264             X, y, np.unique(y), _refit=True, sample_weight=sample_weight
#     265         )
#
# /usr/local/lib/python3.10/dist-packages/sklearn/naive_bayes.py in _partial_fit(self, X, y, classes, _refit, sample_weight)
#     420             self.classes_ = None
#     421
# --> 422         first_call = _check_partial_fit_first_call(self, classes)
#     423         X, y = self._validate_data(X, y, reset=first_call)
#     424         if sample_weight is not None:
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/multiclass.py in _check_partial_fit_first_call(clf, classes)
#     436         else:
#     437             # This is the first call to partial_fit
# --> 438             clf.classes_ = unique_labels(classes)
#     439             return True
#     440
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/multiclass.py in unique_labels(*ys)
#     102     _unique_labels = _FN_UNIQUE_LABELS.get(label_type, None)
#     103     if not _unique_labels:
# --> 104         raise ValueError("Unknown label type: %s" % repr(ys))
#     105
#     106     if is_array_api_compliant:
#
# ValueError: Unknown label type: (array([  50.3,   50.5,   77.7,   86.2,   92.7,  100.7,  105.3,  110.4,
#         124.2,  128.2,  131.4,  151.1,  180.1,  189. ,  193.9,  195.1,
#         222.4,  223. ,  225.3,  242. ,  243. ,  244.2,  246. ,  250. ,
#         250.4,  250.7,  251. ,  253.3,  260.4,  263. ,  266. ,  269. ,
#         270.4,  270.8,  273. ,  275. ,  275.3,  275.8,  277.4,  280.9,
#         282. ,  282.4,  290.8,  298. ,  299. ,  300. ,  304. ,  308. ,
#         310.2,  317.7,  318. ,  318.6,  319.2,  320.4,  323. ,  325.2,
#         327.5,  328. ,  329.3,  329.4,  332.7,  335. ,  335.4,  340. ,
#         341. ,  342.5,  343. ,  345.3,  351.7,  353.2,  357.5,  361. ,
#         361.9,  367.6,  368.5,  374. ,  379.3,  380.2,  380.3,  387.6,
#         390. ,  397.6,  400. ,  406. ,  409.1,  409.4,  415. ,  443. ,
#         466.4,  470.2,  486. ,  500. ,  500.3,  500.4,  563.2,  604.1,
#         643.1,  700. ,  800.3,  800.4,  816. ,  853. ,  953.2, 1000.1,
#        1034.4, 1115. , 1376. , 1500.2, 1729. , 1860.4]),)
