# %%
import numpy as np
import pandas as pd
from sklearn import svm
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score
from sklearn.model_selection import train_test_split

df = pd.read_csv('test.csv')
df
# Out:
#        id  battery_power  blue  clock_speed  dual_sim  ...  sc_w  talk_time  three_g  touch_screen  wifi
# 0       1           1043     1          1.8         1  ...     7          2        0             1     0
# 1       2            841     1          0.5         1  ...     0          7        1             0     0
# 2       3           1807     1          2.8         0  ...    10         10        0             1     1
# 3       4           1546     0          0.5         1  ...     0          7        1             1     0
# 4       5           1434     0          1.4         0  ...     8          7        1             0     1
# ..    ...            ...   ...          ...       ...  ...   ...        ...      ...           ...   ...
# 995   996           1700     1          1.9         0  ...     8         15        1             1     0
# 996   997            609     0          1.8         1  ...     1         19        0             1     1
# 997   998           1185     0          1.4         0  ...     0         14        1             0     0
# 998   999           1533     1          0.5         1  ...    11          6        0             1     0
# 999  1000           1270     1          0.5         0  ...     2          3        1             0     1
#
# [1000 rows x 21 columns]

# %%
df = df.drop(columns=['id'])

# %%
df
# Out:
#      battery_power  blue  clock_speed  dual_sim  fc  ...  sc_w  talk_time  three_g  touch_screen  wifi
# 0             1043     1          1.8         1  14  ...     7          2        0             1     0
# 1              841     1          0.5         1   4  ...     0          7        1             0     0
# 2             1807     1          2.8         0   1  ...    10         10        0             1     1
# 3             1546     0          0.5         1  18  ...     0          7        1             1     0
# 4             1434     0          1.4         0  11  ...     8          7        1             0     1
# ..             ...   ...          ...       ...  ..  ...   ...        ...      ...           ...   ...
# 995           1700     1          1.9         0   0  ...     8         15        1             1     0
# 996            609     0          1.8         1   0  ...     1         19        0             1     1
# 997           1185     0          1.4         0   1  ...     0         14        1             0     0
# 998           1533     1          0.5         1   0  ...    11          6        0             1     0
# 999           1270     1          0.5         0   4  ...     2          3        1             0     1
#
# [1000 rows x 20 columns]

# %%
df.isnull().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# dtype: int64

# %%
for cols in df.columns:
  print(cols, (df[cols] == 0).sum())
# Out:
# battery_power 0
# blue 484
# clock_speed 0
# dual_sim 483
# fc 210
# four_g 513
# int_memory 0
# m_dep 0
# mobile_wt 0
# n_cores 0
# pc 40
# px_height 2
# px_width 0
# ram 0
# sc_h 0
# sc_w 112
# talk_time 0
# three_g 244
# touch_screen 500
# wifi 493

# %%
X = df.drop(columns=['wifi'])
y = df['wifi']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
model = svm.SVC(kernel='poly')
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
print(accuracy_score(y_test, y_pred))
# Out:
# 0.532
